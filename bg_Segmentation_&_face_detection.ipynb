# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("images.jpg")

# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5) 
cnt=1
for (x,y,w,h) in faces: 
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  
    roi_gray = gray[y:y+h, x:x+w] 
    roi_color = img[y:y+h, x:x+w] 

    # Detects eyes of different sizes in the input image 
    eyes = eye_cascade.detectMultiScale(roi_gray)  

    #To draw a rectangle in eyes 
    eye_count=1
    for (ex,ey,ew,eh) in eyes: 
        print('eye_count=',eye_count)
        eye_count=eye_count+1
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,127,255),2) 

# Display an image in a window 
cv2_imshow(img)
# Out:
# face_count= 1
# eye_count= 1
# eye_count= 2
# <PIL.Image.Image image mode=RGB size=201x251 at 0x7FD63AC54320>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("img1.jpg")

img=cv2.resize(img,None,fx=0.2,fy=0.2,interpolation=cv2.INTER_CUBIC)
# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5) 
cnt=1
for (x,y,w,h) in faces: 
    print(faces)
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  
    roi_gray = gray[y:y+h, x:x+w] 
    roi_color = img[y:y+h, x:x+w] 

    # Detects eyes of different sizes in the input image 
    eyes = eye_cascade.detectMultiScale(roi_gray)  

    #To draw a rectangle in eyes 
    eye_count=1
    for (ex,ey,ew,eh) in eyes: 
        print(eyes)
        print('eye_count=',eye_count)
        eye_count=eye_count+1
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,127,255),2) 

# Display an image in a window 
cv2_imshow(img)
# Out:
# [[112  53 108 108]]
# face_count= 1
# [[57 26 30 30]
#  [17 22 28 28]]
# eye_count= 1
# [[57 26 30 30]
#  [17 22 28 28]]
# eye_count= 2
# <PIL.Image.Image image mode=RGB size=319x319 at 0x7FD63AC54208>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("img1.jpg")

img=cv2.resize(img,None,fx=0.1,fy=0.1,interpolation=cv2.INTER_CUBIC)
# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5) 
cnt=1
for (x,y,w,h) in faces: 
    print(faces)
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  
    roi_gray = gray[y:y+h, x:x+w] 
    roi_color = img[y:y+h, x:x+w] 

    # Detects eyes of different sizes in the input image 
    eyes = eye_cascade.detectMultiScale(roi_gray)  

    #To draw a rectangle in eyes 
    eye_count=1
    for (ex,ey,ew,eh) in eyes: 
        print(eyes)
        print('eye_count=',eye_count)
        eye_count=eye_count+1
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,127,255),2) 

# Display an image in a window 
cv2_imshow(img)
# Out:
# [[55 25 56 56]]
# face_count= 1
# [[26 11 21 21]]
# eye_count= 1
# <PIL.Image.Image image mode=RGB size=159x159 at 0x7FD63AD31B00>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("img1.jpg")

img=cv2.resize(img,None,fx=0.05,fy=0.05,interpolation=cv2.INTER_CUBIC)
# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5) 
cnt=1
for (x,y,w,h) in faces: 
    print(faces)
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  
    roi_gray = gray[y:y+h, x:x+w] 
    roi_color = img[y:y+h, x:x+w] 

    # Detects eyes of different sizes in the input image 
    eyes = eye_cascade.detectMultiScale(roi_gray)  

    #To draw a rectangle in eyes 
    eye_count=1
    for (ex,ey,ew,eh) in eyes: 
        print(eyes)
        print('eye_count=',eye_count)
        eye_count=eye_count+1
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,127,255),2) 

# Display an image in a window 
cv2_imshow(img)
# Out:
# [[28 13 27 27]]
# face_count= 1
# <PIL.Image.Image image mode=RGB size=80x80 at 0x7FD63AC63208>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("image.jpg")
# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5) 
cnt=1
for (x,y,w,h) in faces: 
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  
    roi_gray = gray[y:y+h, x:x+w] 
    roi_color = img[y:y+h, x:x+w] 

    # Detects eyes of different sizes in the input image 
    eyes = eye_cascade.detectMultiScale(roi_gray)  

    #To draw a rectangle in eyes 
    eye_count=1
    for (ex,ey,ew,eh) in eyes: 
        print('eye_count=',eye_count)
        eye_count=eye_count+1
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,127,255),2) 

# Display an image in a window 
cv2_imshow(img)
# Out:
# face_count= 1
# eye_count= 1
# eye_count= 2
# face_count= 2
# eye_count= 1
# eye_count= 2
# face_count= 3
# face_count= 4
# eye_count= 1
# eye_count= 2
# face_count= 5
# eye_count= 1
# eye_count= 2
# eye_count= 3
# face_count= 6
# eye_count= 1
# eye_count= 2
# <PIL.Image.Image image mode=RGB size=242x208 at 0x7FD63AC546A0>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("image.jpg")
img=cv2.resize(img,None,fx=2,fy=2,interpolation=cv2.INTER_CUBIC)

# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5) 
cnt=1
for (x,y,w,h) in faces: 
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  
    roi_gray = gray[y:y+h, x:x+w] 
    roi_color = img[y:y+h, x:x+w] 

    # Detects eyes of different sizes in the input image 
    eyes = eye_cascade.detectMultiScale(roi_gray)  

    #To draw a rectangle in eyes 
    eye_count=1
    for (ex,ey,ew,eh) in eyes: 
        print('eye_count=',eye_count)
        eye_count=eye_count+1
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,127,255),2) 

# Display an image in a window 
cv2_imshow(img)
# Out:
# face_count= 1
# eye_count= 1
# eye_count= 2
# face_count= 2
# eye_count= 1
# eye_count= 2
# face_count= 3
# face_count= 4
# eye_count= 1
# eye_count= 2
# face_count= 5
# eye_count= 1
# eye_count= 2
# face_count= 6
# eye_count= 1
# eye_count= 2
# <PIL.Image.Image image mode=RGB size=484x416 at 0x7FD63ACA0278>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("GroupPhoto.jpg")
img=cv2.resize(img,None,fx=0.25,fy=0.25,interpolation=cv2.INTER_CUBIC)

# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5,minSize=(10,10),maxSize=(200,200)) 
cnt=1
for (x,y,w,h) in faces: 
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  

# Display an image in a window 
cv2_imshow(img)
# Out:
# face_count= 1
# face_count= 2
# face_count= 3
# face_count= 4
# face_count= 5
# face_count= 6
# face_count= 7
# <PIL.Image.Image image mode=RGB size=600x297 at 0x7FD63AD057B8>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("GroupPhoto.jpg")
img=cv2.resize(img,None,fx=0.25,fy=0.25,interpolation=cv2.INTER_CUBIC)

# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5,minSize=(60,60),maxSize=(200,200)) 
cnt=1
for (x,y,w,h) in faces: 
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  

# Display an image in a window 
cv2_imshow(img)
# Out:
# face_count= 1
# face_count= 2
# <PIL.Image.Image image mode=RGB size=600x297 at 0x7FD63AFBF390>

# %%
import cv2  
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')  
  
img=cv2.imread("GroupPhoto.jpg")
img=cv2.resize(img,None,fx=0.25,fy=0.25,interpolation=cv2.INTER_CUBIC)

# convert to gray scale of each frames 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

# Detects faces of different sizes in the input image 
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5,minSize=(70,70),maxSize=(200,200)) 
cnt=1
for (x,y,w,h) in faces: 
    print('face_count=',cnt)
    cnt=cnt+1
    # To draw a rectangle in a face  
    cv2.rectangle(img,pt1=(x,y), pt2=(x+w,y+h), color=(255,0,0), thickness=2)  

# Display an image in a window 
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x297 at 0x7FD63AC54710>

# %% [markdown]
# # **Background_Segmentation**

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('pink-ball.jpg')

img1=cv2.resize(img,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_CUBIC)
cv2_imshow(img1)
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

rect = (150,55,450,290)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,50,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]

plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=380x211 at 0x7FADD61ABA20>
# (<matplotlib.image.AxesImage at 0x7fadd5f46f98>,
#  <matplotlib.colorbar.Colorbar at 0x7fadd5ee7470>,
#  None)
